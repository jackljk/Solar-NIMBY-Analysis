# %%
import warnings
import pandas as pd

# Suppress all common warnings that occur during data processing
warnings.filterwarnings("ignore", category=FutureWarning)  # pandas future warnings
warnings.filterwarnings("ignore", category=pd.errors.DtypeWarning)  # mixed dtype warnings
warnings.filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)  # pandas copy warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)  # shapefile/pyogrio warnings
warnings.filterwarnings("ignore", message=".*driver ESRI Shapefile does not support open option DTYPE.*")  # specific pyogrio warning

# Optional: suppress all warnings completely (uncomment if needed)
# warnings.filterwarnings("ignore")

print("Warning suppression configured for data processing")
# Out:
# Warning suppression configured for data processing

# %%
from src.preprocess_data.county_level.CountyDataLoader import CountyDataLoader

# Initialize the CountyDataLoader
county_data_loader = CountyDataLoader()
# Load the data
data = county_data_loader.load_data()

data
# Out:
# ✓ Loaded wind data
# ✓ Loaded solar data
# ✓ Loaded private_schools data
# ✓ Loaded income data
# ✓ Loaded solar data
# ✓ Loaded private_schools data
# ✓ Loaded income data
# ✓ Loaded unemployment data
# ✓ Loaded solar_roof data
# ✓ Loaded gdp data
# ✓ Loaded rural_urban data
# ✓ Loaded decennial race data
# ✓ Loaded all election data
# ✓ Loaded unemployment data
# ✓ Loaded solar_roof data
# ✓ Loaded gdp data
# ✓ Loaded rural_urban data
# ✓ Loaded decennial race data
# ✓ Loaded all election data
# ✓ Loaded 18-24 and 25+ education data
# ✓ Loaded NREL electric price data
# ✓ Loaded 18-24 and 25+ education data
# ✓ Loaded NREL electric price data
#       GEOID STATEFP COUNTYFP    State County Name      area km2      area mi2  \
# 4     01001      01      001  Alabama     Autauga   1565.322757    604.374247
# 5     01003      01      003  Alabama     Baldwin   4352.548564   1680.527706
# 6     01005      01      005  Alabama     Barbour   2342.545642    904.461557
# ...

# %%
county_data_loader.save_to_csv(
    save_type="both",  # Options: "individual", "merged", "both"
)
# Out:
#   ✓ Saved race_data to demographic/race_processed.csv
#   ✓ Saved education_data[18-24] to demographic/education_processed_18-24.csv
#   ✓ Saved education_data[25+] to demographic/education_processed_25+.csv
#   ✓ Saved unemployment_data to demographic/unemployment_processed.csv
#   ✓ Saved income_data to economic/income_processed.csv
#   ✓ Saved electric_data to economic/electric_price_processed.csv
#   ✓ Saved gdp_data to economic/gdp_processed.csv
#   ✓ Saved wind_data to energy/wind_processed.csv
#   ✓ Saved solar_data[all] to energy/solar_processed_all.csv
#   ✓ Saved solar_data[small] to energy/solar_processed_small.csv
#   ✓ Saved solar_data[medium] to energy/solar_processed_medium.csv
#   ✓ Saved solar_data[large] to energy/solar_processed_large.csv
#   ✓ Saved solar_roof_data to energy/solar_roof_processed.csv
#   ✓ Saved private_schools_data to geographic/private_schools_processed.csv
#   ✓ Saved rural_urban_data to geographic/rural_urban_processed.csv
# ...

# %%
from src.preprocess_data.block_group_level.processors.demographic_processors import (
    process_raw_race_data,
    process_raw_education_data,
    process_raw_unemployment_data
)

race = process_raw_race_data("/Users/jack/Documents/Projects/Power-Lab/Solar NIMBY/Solar-NIMBY-Analysis/data/social_factors/block_group_level/demographic_data/race_raw.csv")

# education = process_raw_education_data("/Users/jack/Documents/Projects/Power-Lab/Solar NIMBY/Solar-NIMBY-Analysis/data/social_factors/block_group_level/demographic_data/education_raw.csv")

# unemployment = process_raw_unemployment_data("/Users/jack/Documents/Projects/Power-Lab/Solar NIMBY/Solar-NIMBY-Analysis/data/social_factors/block_group_level/demographic_data/unemployment_raw.csv")

# %%
from src.preprocess_data.block_group_level.processors.economic_processors import (
    process_raw_income_data,
)

income = process_raw_income_data("/Users/jack/Documents/Projects/Power-Lab/Solar NIMBY/Solar-NIMBY-Analysis/data/social_factors/block_group_level/economic_data/income_raw.csv")

# %%
from src.preprocess_data.block_group_level.processors.political_processors import (
    process_raw_election_data,
)

election = process_raw_election_data(
    data_file_path="/Users/jack/Documents/Projects/Power-Lab/Solar NIMBY/Solar-NIMBY-Analysis/data/social_factors/block_group_level/political_data/election_raw.csv",
)
# Out:
# Root directory set to: /Users/jack/Documents/Projects/Power-Lab/Solar NIMBY/Solar-NIMBY-Analysis
# Processing suitability scores for all geographic levels...
# Processing county suitability scores...
# Processing suitability scores for all geographic levels...
# Processing county suitability scores...
# Root directory set to: /Users/jack/Documents/Projects/Power-Lab/Solar NIMBY/Solar-NIMBY-Analysis
# Processing suitability scores for all geographic levels...
# Processing county suitability scores...
# Processing suitability scores for all geographic levels...
# Processing county suitability scores...
# /Users/jack/anaconda3/envs/PowerLab/lib/python3.9/site-packages/pyogrio/raw.py:196: RuntimeWarning: driver ESRI Shapefile does not support open option DTYPE
#   return ogr_read(
# /Users/jack/anaconda3/envs/PowerLab/lib/python3.9/site-packages/pyogrio/raw.py:196: RuntimeWarning: driver ESRI Shapefile does not support open option DTYPE
#   return ogr_read(
# ...

# %%
from src.preprocess_data.block_group_level.processors.energy_processors import (
    process_raw_solar_data,
)

solar = process_raw_solar_data(
    data_file_path="/Users/jack/Documents/Projects/Power-Lab/Solar NIMBY/Solar-NIMBY-Analysis/data/electric_data/solar/solar_raw_block_group.csv", 
    raw_bounding_box_filepath="/Users/jack/Documents/Projects/Power-Lab/Solar NIMBY/Solar-NIMBY-Analysis/data/bounding_boxes/block_group_bounding_box_raw"
)
# Out:
#   ✓ Saved county suitability scores to county_suitability_scores.csv
#     📊 Dataset shape: (3106, 9)
#   ✓ Saved block_group suitability scores to block_group_suitability_scores.csv
#     📊 Dataset shape: (235092, 12)
#   ✓ Saved project suitability scores to project_suitability_scores.csv
#     📊 Dataset shape: (4140, 14)
#   📁 Saved 3 suitability datasets
# ✓ Suitability scores saved to /Users/jack/Documents/Projects/Power-Lab/Solar NIMBY/Solar-NIMBY-Analysis/data_processed/suitability_scores
#   ✓ Saved block_group suitability scores to block_group_suitability_scores.csv
#     📊 Dataset shape: (235092, 12)
#   ✓ Saved project suitability scores to project_suitability_scores.csv
#     📊 Dataset shape: (4140, 14)
#   📁 Saved 3 suitability datasets
# ✓ Suitability scores saved to /Users/jack/Documents/Projects/Power-Lab/Solar NIMBY/Solar-NIMBY-Analysis/data_processed/suitability_scores

# %%
# Test the new save_to_csv functionality for suitability scores

# Get summary of what's available to save
save_summary = suitability_score_loader.get_save_summary()
print("Suitability Scores Save Summary:")
print(f"Total datasets: {save_summary['total_datasets']}")
print(f"Total DataFrames: {save_summary['total_dataframes']}")
print(f"Geographic level: {save_summary['configuration']['geographic_level']}")
print("\nAvailable datasets:")
for level, info in save_summary['available_datasets'].items():
    if info['type'] == 'DataFrame':
        print(f"  {level}: {info['shape']}")
    else:
        print(f"  {level}: {info['type']}")

print("\n" + "="*60)

# Save the suitability scores (uncomment to actually save)
# suitability_score_loader.save_to_csv(save_type="both")

print("Ready to save suitability scores - uncomment the line above to save to disk")race.head()
# Out:
#   State County   Tract Block Group State Name County Name  Total Population  \
# 0    01    001  020100           1       None        None               575
# 1    01    001  020100           2       None        None              1200
# 2    01    001  020200           1       None        None               974
# 3    01    001  020200           2       None        None              1081
# 4    01    001  020300           1       None        None              2377
#
#    Total One Race  White Only  African American Only  \
# 0             523         433                     73
# 1            1130         956                    140
# 2             942         311                    615
# 3            1042         531                    489
# 4            2243        1672                    499
#
#    American Indian and Alaska Native Only  Asian Only  \
# 0                                       0           5
# 1                                       5           3
# ...

# %%
from src.preprocess_data.block_group_level.BlockGroupDataLoader import BlockGroupDataLoader

# Initialize the BlockGroupDataLoader
block_group_data_loader = BlockGroupDataLoader()
# Load the data
data = block_group_data_loader.load_data()

data
# Out:
# Root directory set to: /Users/jack/Documents/Projects/Power-Lab/Solar NIMBY/Solar-NIMBY-Analysis
# /Users/jack/anaconda3/envs/PowerLab/lib/python3.9/site-packages/pyogrio/raw.py:196: RuntimeWarning: driver ESRI Shapefile does not support open option DTYPE
#   return ogr_read(
# ✓ Loaded race data
# ✓ Loaded education data
# ✓ Loaded unemployment data
# ✓ Loaded income data
# ✓ Loaded election data
# /Users/jack/anaconda3/envs/PowerLab/lib/python3.9/site-packages/pyogrio/raw.py:196: RuntimeWarning: driver ESRI Shapefile does not support open option DTYPE
#   return ogr_read(
# /Users/jack/anaconda3/envs/PowerLab/lib/python3.9/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
