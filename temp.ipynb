# %%
import pandas as pd

# %%
from src.block_group_level.bounding_box_utils import process_raw_block_group_bounding_box

process_raw_block_group_bounding_box("/Users/jack/Library/CloudStorage/GoogleDrive-limjackailjk@gmail.com/My Drive/Research/NIMBY Project/NIMBY Project/Solar NIMBY Final/Final/data/bounding_boxes/block_group_bounding_box_raw")
# Out:
# Root directory set to: /Users/jack/Library/CloudStorage/GoogleDrive-limjackailjk@gmail.com/My Drive/Research/NIMBY Project/NIMBY Project/Solar NIMBY Final/Final
# /Users/jack/anaconda3/envs/PowerLab/lib/python3.9/site-packages/pyogrio/raw.py:196: RuntimeWarning: driver ESRI Shapefile does not support open option DTYPE
#   return ogr_read(
#                GEOID STATEFP COUNTYFP TRACTCE BLKGRPCE       State  \
# 0       011130303001      01      113  030300        1     Alabama
# 1       040159534062      04      015  953406        2     Arizona
# 2       040019450021      04      001  945002        1     Arizona
# 3       040270003012      04      027  000301        2     Arizona
# 4       050070208033      05      007  020803        3    Arkansas
# ...              ...     ...      ...     ...      ...         ...
# 235087  100050513121      10      005  051312        1    Delaware
# 235088  260172855005      26      017  285500        5    Michigan
# ...

# %%
from src.county_level.bounding_box_utils import process_raw_county_bounding_box

process_raw_county_bounding_box("/Users/jack/Library/CloudStorage/GoogleDrive-limjackailjk@gmail.com/My Drive/Research/NIMBY Project/NIMBY Project/Solar NIMBY Final/Final/data/bounding_boxes/county_bounding_box_raw")
# Out:
# /Users/jack/anaconda3/envs/PowerLab/lib/python3.9/site-packages/pyogrio/raw.py:196: RuntimeWarning: driver ESRI Shapefile does not support open option DTYPE
#   return ogr_read(
#       GEOID STATEFP COUNTYFP      State County Name     area km2     area mi2
# 0     21007      21      007   Kentucky     Ballard   708.542173   273.569550
# 1     21017      21      017   Kentucky     Bourbon   755.280071   291.615146
# 2     21031      21      031   Kentucky      Butler  1117.793121   431.582160
# 3     21065      21      065   Kentucky      Estill   662.202105   255.677557
# 4     21069      21      069   Kentucky     Fleming   909.915069   351.320028
# ...     ...     ...      ...        ...         ...          ...          ...
# 3101  31073      31      073   Nebraska      Gosper  1198.343327   462.682755
# 3102  39075      39      075       Ohio      Holmes  1098.123388   423.987636
# 3103  48171      48      171      Texas   Gillespie  2749.614403  1061.631620
# ...
